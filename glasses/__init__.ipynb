# %%
__version__ = "0.0.1"

__all__ = []

# %%
from time import sleep

# %%
# %ls /Users/tfast/Desktop/SLAC_MG_0716/
# Out:
# Sample1/          Sample15_7thick/  Sample2_annealed/ Sample6/
# Sample10/         Sample16_2thin/   Sample3/          Sample7_annealed/
# Sample11/         Sample17/         Sample4/          Sample8/
# Sample14_7thin/   Sample18/         Sample5/          filenames.txt*

# %%
# %ls /Users/tfast/Desktop/SLAC_MG_0716/Sample1/
# Out:
# Processed/                       Sample1_24x24_t30_0221.txt*
# Sample1_24x24_t30*               Sample1_24x24_t30_0222.tif*
# Sample1_24x24_t30_0001.tif*      Sample1_24x24_t30_0222.txt*
# Sample1_24x24_t30_0001.txt*      Sample1_24x24_t30_0223.tif*
# Sample1_24x24_t30_0002.tif*      Sample1_24x24_t30_0223.txt*
# Sample1_24x24_t30_0002.txt*      Sample1_24x24_t30_0224.tif*
# Sample1_24x24_t30_0003.tif*      Sample1_24x24_t30_0224.txt*
# Sample1_24x24_t30_0003.txt*      Sample1_24x24_t30_0225.tif*
# Sample1_24x24_t30_0004.tif*      Sample1_24x24_t30_0225.txt*
# Sample1_24x24_t30_0004.txt*      Sample1_24x24_t30_0226.tif*
# Sample1_24x24_t30_0005.tif*      Sample1_24x24_t30_0226.txt*
# Sample1_24x24_t30_0005.txt*      Sample1_24x24_t30_0227.tif*
# Sample1_24x24_t30_0006.tif*      Sample1_24x24_t30_0227.txt*
# Sample1_24x24_t30_0006.txt*      Sample1_24x24_t30_0228.tif*
# Sample1_24x24_t30_0007.tif*      Sample1_24x24_t30_0228.txt*
# Sample1_24x24_t30_0007.txt*      Sample1_24x24_t30_0229.tif*
# Sample1_24x24_t30_0008.tif*      Sample1_24x24_t30_0229.txt*
# Sample1_24x24_t30_0008.txt*      Sample1_24x24_t30_0230.tif*
# Sample1_24x24_t30_0009.tif*      Sample1_24x24_t30_0230.txt*
# Sample1_24x24_t30_0009.txt*      Sample1_24x24_t30_0231.tif*
# Sample1_24x24_t30_0010.tif*      Sample1_24x24_t30_0231.txt*
# Sample1_24x24_t30_0010.txt*      Sample1_24x24_t30_0232.tif*
# Sample1_24x24_t30_0011.tif*      Sample1_24x24_t30_0232.txt*
# Sample1_24x24_t30_0011.txt*      Sample1_24x24_t30_0233.tif*
# Sample1_24x24_t30_0012.tif*      Sample1_24x24_t30_0233.txt*
# Sample1_24x24_t30_0012.txt*      Sample1_24x24_t30_0234.tif*
# Sample1_24x24_t30_0013.tif*      Sample1_24x24_t30_0234.txt*
# Sample1_24x24_t30_0013.txt*      Sample1_24x24_t30_0235.tif*
# Sample1_24x24_t30_0014.tif*      Sample1_24x24_t30_0235.txt*
# Sample1_24x24_t30_0014.txt*      Sample1_24x24_t30_0236.tif*
# Sample1_24x24_t30_0015.tif*      Sample1_24x24_t30_0236.txt*
# Sample1_24x24_t30_0015.txt*      Sample1_24x24_t30_0237.tif*
# Sample1_24x24_t30_0016.tif*      Sample1_24x24_t30_0237.txt*
# Sample1_24x24_t30_0016.txt*      Sample1_24x24_t30_0238.tif*
# Sample1_24x24_t30_0017.tif*      Sample1_24x24_t30_0238.txt*
# Sample1_24x24_t30_0017.txt*      Sample1_24x24_t30_0239.tif*
# Sample1_24x24_t30_0018.tif*      Sample1_24x24_t30_0239.txt*
# Sample1_24x24_t30_0018.txt*      Sample1_24x24_t30_0240.tif*
# Sample1_24x24_t30_0019.tif*      Sample1_24x24_t30_0240.txt*
# Sample1_24x24_t30_0019.txt*      Sample1_24x24_t30_0241.tif*
# Sample1_24x24_t30_0020.tif*      Sample1_24x24_t30_0241.txt*
# Sample1_24x24_t30_0020.txt*      Sample1_24x24_t30_0242.tif*
# Sample1_24x24_t30_0021.tif*      Sample1_24x24_t30_0242.txt*
# Sample1_24x24_t30_0021.txt*      Sample1_24x24_t30_0243.tif*
# Sample1_24x24_t30_0022.tif*      Sample1_24x24_t30_0243.txt*
# Sample1_24x24_t30_0022.txt*      Sample1_24x24_t30_0244.tif*
# Sample1_24x24_t30_0023.tif*      Sample1_24x24_t30_0244.txt*
# Sample1_24x24_t30_0023.txt*      Sample1_24x24_t30_0245.tif*
# Sample1_24x24_t30_0024.tif*      Sample1_24x24_t30_0245.txt*
# Sample1_24x24_t30_0024.txt*      Sample1_24x24_t30_0246.tif*
# Sample1_24x24_t30_0025.tif*      Sample1_24x24_t30_0246.txt*
# Sample1_24x24_t30_0025.txt*      Sample1_24x24_t30_0247.tif*
# Sample1_24x24_t30_0026.tif*      Sample1_24x24_t30_0247.txt*
# Sample1_24x24_t30_0026.txt*      Sample1_24x24_t30_0248.tif*
# Sample1_24x24_t30_0027.tif*      Sample1_24x24_t30_0248.txt*
# Sample1_24x24_t30_0027.txt*      Sample1_24x24_t30_0249.tif*
# Sample1_24x24_t30_0028.tif*      Sample1_24x24_t30_0249.txt*
# Sample1_24x24_t30_0028.txt*      Sample1_24x24_t30_0250.tif*
# Sample1_24x24_t30_0029.tif*      Sample1_24x24_t30_0250.txt*
# Sample1_24x24_t30_0029.txt*      Sample1_24x24_t30_0251.tif*
# Sample1_24x24_t30_0030.tif*      Sample1_24x24_t30_0251.txt*
# Sample1_24x24_t30_0030.txt*      Sample1_24x24_t30_0252.tif*
# Sample1_24x24_t30_0031.tif*      Sample1_24x24_t30_0252.txt*
# Sample1_24x24_t30_0031.txt*      Sample1_24x24_t30_0253.tif*
# Sample1_24x24_t30_0032.tif*      Sample1_24x24_t30_0253.txt*
# Sample1_24x24_t30_0032.txt*      Sample1_24x24_t30_0254.tif*
# Sample1_24x24_t30_0033.tif*      Sample1_24x24_t30_0254.txt*
# Sample1_24x24_t30_0033.txt*      Sample1_24x24_t30_0255.tif*
# Sample1_24x24_t30_0034.tif*      Sample1_24x24_t30_0255.txt*
# Sample1_24x24_t30_0034.txt*      Sample1_24x24_t30_0256.tif*
# Sample1_24x24_t30_0035.tif*      Sample1_24x24_t30_0256.txt*
# Sample1_24x24_t30_0035.txt*      Sample1_24x24_t30_0257.tif*
# Sample1_24x24_t30_0036.tif*      Sample1_24x24_t30_0257.txt*
# Sample1_24x24_t30_0036.txt*      Sample1_24x24_t30_0258.tif*
# Sample1_24x24_t30_0037.tif*      Sample1_24x24_t30_0258.txt*
# Sample1_24x24_t30_0037.txt*      Sample1_24x24_t30_0259.tif*
# Sample1_24x24_t30_0038.tif*      Sample1_24x24_t30_0259.txt*
# Sample1_24x24_t30_0038.txt*      Sample1_24x24_t30_0260.tif*
# Sample1_24x24_t30_0039.tif*      Sample1_24x24_t30_0260.txt*
# Sample1_24x24_t30_0039.txt*      Sample1_24x24_t30_0261.tif*
# Sample1_24x24_t30_0040.tif*      Sample1_24x24_t30_0261.txt*
# Sample1_24x24_t30_0040.txt*      Sample1_24x24_t30_0262.tif*
# Sample1_24x24_t30_0041.tif*      Sample1_24x24_t30_0262.txt*
# Sample1_24x24_t30_0041.txt*      Sample1_24x24_t30_0263.tif*
# Sample1_24x24_t30_0042.tif*      Sample1_24x24_t30_0263.txt*
# Sample1_24x24_t30_0042.txt*      Sample1_24x24_t30_0264.tif*
# Sample1_24x24_t30_0043.tif*      Sample1_24x24_t30_0264.txt*
# Sample1_24x24_t30_0043.txt*      Sample1_24x24_t30_0265.tif*
# Sample1_24x24_t30_0044.tif*      Sample1_24x24_t30_0265.txt*
# Sample1_24x24_t30_0044.txt*      Sample1_24x24_t30_0266.tif*
# Sample1_24x24_t30_0045.tif*      Sample1_24x24_t30_0266.txt*
# Sample1_24x24_t30_0045.txt*      Sample1_24x24_t30_0267.tif*
# Sample1_24x24_t30_0046.tif*      Sample1_24x24_t30_0267.txt*
# Sample1_24x24_t30_0046.txt*      Sample1_24x24_t30_0268.tif*
# Sample1_24x24_t30_0047.tif*      Sample1_24x24_t30_0268.txt*
# Sample1_24x24_t30_0047.txt*      Sample1_24x24_t30_0269.tif*
# Sample1_24x24_t30_0048.tif*      Sample1_24x24_t30_0269.txt*
# Sample1_24x24_t30_0048.txt*      Sample1_24x24_t30_0270.tif*
# Sample1_24x24_t30_0049.tif*      Sample1_24x24_t30_0270.txt*
# Sample1_24x24_t30_0049.txt*      Sample1_24x24_t30_0271.tif*
# Sample1_24x24_t30_0050.tif*      Sample1_24x24_t30_0271.txt*
# Sample1_24x24_t30_0050.txt*      Sample1_24x24_t30_0272.tif*
# Sample1_24x24_t30_0051.tif*      Sample1_24x24_t30_0272.txt*
# Sample1_24x24_t30_0051.txt*      Sample1_24x24_t30_0273.tif*
# Sample1_24x24_t30_0052.tif*      Sample1_24x24_t30_0273.txt*
# Sample1_24x24_t30_0052.txt*      Sample1_24x24_t30_0274.tif*
# Sample1_24x24_t30_0053.tif*      Sample1_24x24_t30_0274.txt*
# Sample1_24x24_t30_0053.txt*      Sample1_24x24_t30_0275.tif*
# Sample1_24x24_t30_0054.tif*      Sample1_24x24_t30_0275.txt*
# Sample1_24x24_t30_0054.txt*      Sample1_24x24_t30_0276.tif*
# Sample1_24x24_t30_0055.tif*      Sample1_24x24_t30_0276.txt*
# Sample1_24x24_t30_0055.txt*      Sample1_24x24_t30_0277.tif*
# Sample1_24x24_t30_0056.tif*      Sample1_24x24_t30_0277.txt*
# Sample1_24x24_t30_0056.txt*      Sample1_24x24_t30_0278.tif*
# Sample1_24x24_t30_0057.tif*      Sample1_24x24_t30_0278.txt*
# Sample1_24x24_t30_0057.txt*      Sample1_24x24_t30_0279.tif*
# Sample1_24x24_t30_0058.tif*      Sample1_24x24_t30_0279.txt*
# Sample1_24x24_t30_0058.txt*      Sample1_24x24_t30_0280.tif*
# Sample1_24x24_t30_0059.tif*      Sample1_24x24_t30_0280.txt*
# Sample1_24x24_t30_0059.txt*      Sample1_24x24_t30_0281.tif*
# Sample1_24x24_t30_0060.tif*      Sample1_24x24_t30_0281.txt*
# Sample1_24x24_t30_0060.txt*      Sample1_24x24_t30_0282.tif*
# Sample1_24x24_t30_0061.tif*      Sample1_24x24_t30_0282.txt*
# Sample1_24x24_t30_0061.txt*      Sample1_24x24_t30_0283.tif*
# Sample1_24x24_t30_0062.tif*      Sample1_24x24_t30_0283.txt*
# Sample1_24x24_t30_0062.txt*      Sample1_24x24_t30_0284.tif*
# Sample1_24x24_t30_0063.tif*      Sample1_24x24_t30_0284.txt*
# Sample1_24x24_t30_0063.txt*      Sample1_24x24_t30_0285.tif*
# Sample1_24x24_t30_0064.tif*      Sample1_24x24_t30_0285.txt*
# Sample1_24x24_t30_0064.txt*      Sample1_24x24_t30_0286.tif*
# Sample1_24x24_t30_0065.tif*      Sample1_24x24_t30_0286.txt*
# Sample1_24x24_t30_0065.txt*      Sample1_24x24_t30_0287.tif*
# Sample1_24x24_t30_0066.tif*      Sample1_24x24_t30_0287.txt*
# Sample1_24x24_t30_0066.txt*      Sample1_24x24_t30_0288.tif*
# Sample1_24x24_t30_0067.tif*      Sample1_24x24_t30_0288.txt*
# Sample1_24x24_t30_0067.txt*      Sample1_24x24_t30_0289.tif*
# Sample1_24x24_t30_0068.tif*      Sample1_24x24_t30_0289.txt*
# Sample1_24x24_t30_0068.txt*      Sample1_24x24_t30_0290.tif*
# Sample1_24x24_t30_0069.tif*      Sample1_24x24_t30_0290.txt*
# Sample1_24x24_t30_0069.txt*      Sample1_24x24_t30_0291.tif*
# Sample1_24x24_t30_0070.tif*      Sample1_24x24_t30_0291.txt*
# Sample1_24x24_t30_0070.txt*      Sample1_24x24_t30_0292.tif*
# Sample1_24x24_t30_0071.tif*      Sample1_24x24_t30_0292.txt*
# Sample1_24x24_t30_0071.txt*      Sample1_24x24_t30_0293.tif*
# Sample1_24x24_t30_0072.tif*      Sample1_24x24_t30_0293.txt*
# Sample1_24x24_t30_0072.txt*      Sample1_24x24_t30_0294.tif*
# Sample1_24x24_t30_0073.tif*      Sample1_24x24_t30_0294.txt*
# Sample1_24x24_t30_0073.txt*      Sample1_24x24_t30_0295.tif*
# Sample1_24x24_t30_0074.tif*      Sample1_24x24_t30_0295.txt*
# Sample1_24x24_t30_0074.txt*      Sample1_24x24_t30_0296.tif*
# Sample1_24x24_t30_0075.tif*      Sample1_24x24_t30_0296.txt*
# Sample1_24x24_t30_0075.txt*      Sample1_24x24_t30_0297.tif*
# Sample1_24x24_t30_0076.tif*      Sample1_24x24_t30_0297.txt*
# Sample1_24x24_t30_0076.txt*      Sample1_24x24_t30_0298.tif*
# Sample1_24x24_t30_0077.tif*      Sample1_24x24_t30_0298.txt*
# Sample1_24x24_t30_0077.txt*      Sample1_24x24_t30_0299.tif*
# Sample1_24x24_t30_0078.tif*      Sample1_24x24_t30_0299.txt*
# Sample1_24x24_t30_0078.txt*      Sample1_24x24_t30_0300.tif*
# Sample1_24x24_t30_0079.tif*      Sample1_24x24_t30_0300.txt*
# Sample1_24x24_t30_0079.txt*      Sample1_24x24_t30_0301.tif*
# Sample1_24x24_t30_0080.tif*      Sample1_24x24_t30_0301.txt*
# Sample1_24x24_t30_0080.txt*      Sample1_24x24_t30_0302.tif*
# Sample1_24x24_t30_0081.tif*      Sample1_24x24_t30_0302.txt*
# Sample1_24x24_t30_0081.txt*      Sample1_24x24_t30_0303.tif*
# Sample1_24x24_t30_0082.tif*      Sample1_24x24_t30_0303.txt*
# Sample1_24x24_t30_0082.txt*      Sample1_24x24_t30_0304.tif*
# Sample1_24x24_t30_0083.tif*      Sample1_24x24_t30_0304.txt*
# Sample1_24x24_t30_0083.txt*      Sample1_24x24_t30_0305.tif*
# Sample1_24x24_t30_0084.tif*      Sample1_24x24_t30_0305.txt*
# Sample1_24x24_t30_0084.txt*      Sample1_24x24_t30_0306.tif*
# Sample1_24x24_t30_0085.tif*      Sample1_24x24_t30_0306.txt*
# Sample1_24x24_t30_0085.txt*      Sample1_24x24_t30_0307.tif*
# Sample1_24x24_t30_0086.tif*      Sample1_24x24_t30_0307.txt*
# Sample1_24x24_t30_0086.txt*      Sample1_24x24_t30_0308.tif*
# Sample1_24x24_t30_0087.tif*      Sample1_24x24_t30_0308.txt*
# Sample1_24x24_t30_0087.txt*      Sample1_24x24_t30_0309.tif*
# Sample1_24x24_t30_0088.tif*      Sample1_24x24_t30_0309.txt*
# Sample1_24x24_t30_0088.txt*      Sample1_24x24_t30_0310.tif*
# Sample1_24x24_t30_0089.tif*      Sample1_24x24_t30_0310.txt*
# Sample1_24x24_t30_0089.txt*      Sample1_24x24_t30_0311.tif*
# Sample1_24x24_t30_0090.tif*      Sample1_24x24_t30_0311.txt*
# Sample1_24x24_t30_0090.txt*      Sample1_24x24_t30_0312.tif*
# Sample1_24x24_t30_0091.tif*      Sample1_24x24_t30_0312.txt*
# Sample1_24x24_t30_0091.txt*      Sample1_24x24_t30_0313.tif*
# Sample1_24x24_t30_0092.tif*      Sample1_24x24_t30_0313.txt*
# Sample1_24x24_t30_0092.txt*      Sample1_24x24_t30_0314.tif*
# Sample1_24x24_t30_0093.tif*      Sample1_24x24_t30_0314.txt*
# Sample1_24x24_t30_0093.txt*      Sample1_24x24_t30_0315.tif*
# Sample1_24x24_t30_0094.tif*      Sample1_24x24_t30_0315.txt*
# Sample1_24x24_t30_0094.txt*      Sample1_24x24_t30_0316.tif*
# Sample1_24x24_t30_0095.tif*      Sample1_24x24_t30_0316.txt*
# Sample1_24x24_t30_0095.txt*      Sample1_24x24_t30_0317.tif*
# Sample1_24x24_t30_0096.tif*      Sample1_24x24_t30_0317.txt*
# Sample1_24x24_t30_0096.txt*      Sample1_24x24_t30_0318.tif*
# Sample1_24x24_t30_0097.tif*      Sample1_24x24_t30_0318.txt*
# Sample1_24x24_t30_0097.txt*      Sample1_24x24_t30_0319.tif*
# Sample1_24x24_t30_0098.tif*      Sample1_24x24_t30_0319.txt*
# Sample1_24x24_t30_0098.txt*      Sample1_24x24_t30_0320.tif*
# Sample1_24x24_t30_0099.tif*      Sample1_24x24_t30_0320.txt*
# Sample1_24x24_t30_0099.txt*      Sample1_24x24_t30_0321.tif*
# Sample1_24x24_t30_0100.tif*      Sample1_24x24_t30_0321.txt*
# Sample1_24x24_t30_0100.txt*      Sample1_24x24_t30_0322.tif*
# Sample1_24x24_t30_0101.tif*      Sample1_24x24_t30_0322.txt*
# Sample1_24x24_t30_0101.txt*      Sample1_24x24_t30_0323.tif*
# Sample1_24x24_t30_0102.tif*      Sample1_24x24_t30_0323.txt*
# Sample1_24x24_t30_0102.txt*      Sample1_24x24_t30_0324.tif*
# Sample1_24x24_t30_0103.tif*      Sample1_24x24_t30_0324.txt*
# Sample1_24x24_t30_0103.txt*      Sample1_24x24_t30_0325.tif*
# Sample1_24x24_t30_0104.tif*      Sample1_24x24_t30_0325.txt*
# Sample1_24x24_t30_0104.txt*      Sample1_24x24_t30_0326.tif*
# Sample1_24x24_t30_0105.tif*      Sample1_24x24_t30_0326.txt*
# Sample1_24x24_t30_0105.txt*      Sample1_24x24_t30_0327.tif*
# Sample1_24x24_t30_0106.tif*      Sample1_24x24_t30_0327.txt*
# Sample1_24x24_t30_0106.txt*      Sample1_24x24_t30_0328.tif*
# Sample1_24x24_t30_0107.tif*      Sample1_24x24_t30_0328.txt*
# Sample1_24x24_t30_0107.txt*      Sample1_24x24_t30_0329.tif*
# Sample1_24x24_t30_0108.tif*      Sample1_24x24_t30_0329.txt*
# Sample1_24x24_t30_0108.txt*      Sample1_24x24_t30_0330.tif*
# Sample1_24x24_t30_0109.tif*      Sample1_24x24_t30_0330.txt*
# Sample1_24x24_t30_0109.txt*      Sample1_24x24_t30_0331.tif*
# Sample1_24x24_t30_0110.tif*      Sample1_24x24_t30_0331.txt*
# Sample1_24x24_t30_0110.txt*      Sample1_24x24_t30_0332.tif*
# Sample1_24x24_t30_0111.tif*      Sample1_24x24_t30_0332.txt*
# Sample1_24x24_t30_0111.txt*      Sample1_24x24_t30_0333.tif*
# Sample1_24x24_t30_0112.tif*      Sample1_24x24_t30_0333.txt*
# Sample1_24x24_t30_0112.txt*      Sample1_24x24_t30_0334.tif*
# Sample1_24x24_t30_0113.tif*      Sample1_24x24_t30_0334.txt*
# Sample1_24x24_t30_0113.txt*      Sample1_24x24_t30_0335.tif*
# Sample1_24x24_t30_0114.tif*      Sample1_24x24_t30_0335.txt*
# Sample1_24x24_t30_0114.txt*      Sample1_24x24_t30_0336.tif*
# Sample1_24x24_t30_0115.tif*      Sample1_24x24_t30_0336.txt*
# Sample1_24x24_t30_0115.txt*      Sample1_24x24_t30_0337.tif*
# Sample1_24x24_t30_0116.tif*      Sample1_24x24_t30_0337.txt*
# Sample1_24x24_t30_0116.txt*      Sample1_24x24_t30_0338.tif*
# Sample1_24x24_t30_0117.tif*      Sample1_24x24_t30_0338.txt*
# Sample1_24x24_t30_0117.txt*      Sample1_24x24_t30_0339.tif*
# Sample1_24x24_t30_0118.tif*      Sample1_24x24_t30_0339.txt*
# Sample1_24x24_t30_0118.txt*      Sample1_24x24_t30_0340.tif*
# Sample1_24x24_t30_0119.tif*      Sample1_24x24_t30_0340.txt*
# Sample1_24x24_t30_0119.txt*      Sample1_24x24_t30_0341.tif*
# Sample1_24x24_t30_0120.tif*      Sample1_24x24_t30_0341.txt*
# Sample1_24x24_t30_0120.txt*      Sample1_24x24_t30_0342.tif*
# Sample1_24x24_t30_0121.tif*      Sample1_24x24_t30_0342.txt*
# Sample1_24x24_t30_0121.txt*      Sample1_24x24_t30_0343.tif*
# Sample1_24x24_t30_0122.tif*      Sample1_24x24_t30_0343.txt*
# Sample1_24x24_t30_0122.txt*      Sample1_24x24_t30_0344.tif*
# Sample1_24x24_t30_0123.tif*      Sample1_24x24_t30_0344.txt*
# Sample1_24x24_t30_0123.txt*      Sample1_24x24_t30_0345.tif*
# Sample1_24x24_t30_0124.tif*      Sample1_24x24_t30_0345.txt*
# Sample1_24x24_t30_0124.txt*      Sample1_24x24_t30_0346.tif*
# Sample1_24x24_t30_0125.tif*      Sample1_24x24_t30_0346.txt*
# Sample1_24x24_t30_0125.txt*      Sample1_24x24_t30_0347.tif*
# Sample1_24x24_t30_0126.tif*      Sample1_24x24_t30_0347.txt*
# Sample1_24x24_t30_0126.txt*      Sample1_24x24_t30_0348.tif*
# Sample1_24x24_t30_0127.tif*      Sample1_24x24_t30_0348.txt*
# Sample1_24x24_t30_0127.txt*      Sample1_24x24_t30_0349.tif*
# Sample1_24x24_t30_0128.tif*      Sample1_24x24_t30_0349.txt*
# Sample1_24x24_t30_0128.txt*      Sample1_24x24_t30_0350.tif*
# Sample1_24x24_t30_0129.tif*      Sample1_24x24_t30_0350.txt*
# Sample1_24x24_t30_0129.txt*      Sample1_24x24_t30_0351.tif*
# Sample1_24x24_t30_0130.tif*      Sample1_24x24_t30_0351.txt*
# Sample1_24x24_t30_0130.txt*      Sample1_24x24_t30_0352.tif*
# Sample1_24x24_t30_0131.tif*      Sample1_24x24_t30_0352.txt*
# Sample1_24x24_t30_0131.txt*      Sample1_24x24_t30_0353.tif*
# Sample1_24x24_t30_0132.tif*      Sample1_24x24_t30_0353.txt*
# Sample1_24x24_t30_0132.txt*      Sample1_24x24_t30_0354.tif*
# Sample1_24x24_t30_0133.tif*      Sample1_24x24_t30_0354.txt*
# Sample1_24x24_t30_0133.txt*      Sample1_24x24_t30_0355.tif*
# Sample1_24x24_t30_0134.tif*      Sample1_24x24_t30_0355.txt*
# Sample1_24x24_t30_0134.txt*      Sample1_24x24_t30_0356.tif*
# Sample1_24x24_t30_0135.tif*      Sample1_24x24_t30_0356.txt*
# Sample1_24x24_t30_0135.txt*      Sample1_24x24_t30_0357.tif*
# Sample1_24x24_t30_0136.tif*      Sample1_24x24_t30_0357.txt*
# Sample1_24x24_t30_0136.txt*      Sample1_24x24_t30_0358.tif*
# Sample1_24x24_t30_0137.tif*      Sample1_24x24_t30_0358.txt*
# Sample1_24x24_t30_0137.txt*      Sample1_24x24_t30_0359.tif*
# Sample1_24x24_t30_0138.tif*      Sample1_24x24_t30_0359.txt*
# Sample1_24x24_t30_0138.txt*      Sample1_24x24_t30_0360.tif*
# Sample1_24x24_t30_0139.tif*      Sample1_24x24_t30_0360.txt*
# Sample1_24x24_t30_0139.txt*      Sample1_24x24_t30_0361.tif*
# Sample1_24x24_t30_0140.tif*      Sample1_24x24_t30_0361.txt*
# Sample1_24x24_t30_0140.txt*      Sample1_24x24_t30_0362.tif*
# Sample1_24x24_t30_0141.tif*      Sample1_24x24_t30_0362.txt*
# Sample1_24x24_t30_0141.txt*      Sample1_24x24_t30_0363.tif*
# Sample1_24x24_t30_0142.tif*      Sample1_24x24_t30_0363.txt*
# Sample1_24x24_t30_0142.txt*      Sample1_24x24_t30_0364.tif*
# Sample1_24x24_t30_0143.tif*      Sample1_24x24_t30_0364.txt*
# Sample1_24x24_t30_0143.txt*      Sample1_24x24_t30_0365.tif*
# Sample1_24x24_t30_0144.tif*      Sample1_24x24_t30_0365.txt*
# Sample1_24x24_t30_0144.txt*      Sample1_24x24_t30_0366.tif*
# Sample1_24x24_t30_0145.tif*      Sample1_24x24_t30_0366.txt*
# Sample1_24x24_t30_0145.txt*      Sample1_24x24_t30_0367.tif*
# Sample1_24x24_t30_0146.tif*      Sample1_24x24_t30_0367.txt*
# Sample1_24x24_t30_0146.txt*      Sample1_24x24_t30_0368.tif*
# Sample1_24x24_t30_0147.tif*      Sample1_24x24_t30_0368.txt*
# Sample1_24x24_t30_0147.txt*      Sample1_24x24_t30_0369.tif*
# Sample1_24x24_t30_0148.tif*      Sample1_24x24_t30_0369.txt*
# Sample1_24x24_t30_0148.txt*      Sample1_24x24_t30_0370.tif*
# Sample1_24x24_t30_0149.tif*      Sample1_24x24_t30_0370.txt*
# Sample1_24x24_t30_0149.txt*      Sample1_24x24_t30_0371.tif*
# Sample1_24x24_t30_0150.tif*      Sample1_24x24_t30_0371.txt*
# Sample1_24x24_t30_0150.txt*      Sample1_24x24_t30_0372.tif*
# Sample1_24x24_t30_0151.tif*      Sample1_24x24_t30_0372.txt*
# Sample1_24x24_t30_0151.txt*      Sample1_24x24_t30_0373.tif*
# Sample1_24x24_t30_0152.tif*      Sample1_24x24_t30_0373.txt*
# Sample1_24x24_t30_0152.txt*      Sample1_24x24_t30_0374.tif*
# Sample1_24x24_t30_0153.tif*      Sample1_24x24_t30_0374.txt*
# Sample1_24x24_t30_0153.txt*      Sample1_24x24_t30_0375.tif*
# Sample1_24x24_t30_0154.tif*      Sample1_24x24_t30_0375.txt*
# Sample1_24x24_t30_0154.txt*      Sample1_24x24_t30_0376.tif*
# Sample1_24x24_t30_0155.tif*      Sample1_24x24_t30_0376.txt*
# Sample1_24x24_t30_0155.txt*      Sample1_24x24_t30_0377.tif*
# Sample1_24x24_t30_0156.tif*      Sample1_24x24_t30_0377.txt*
# Sample1_24x24_t30_0156.txt*      Sample1_24x24_t30_0378.tif*
# Sample1_24x24_t30_0157.tif*      Sample1_24x24_t30_0378.txt*
# Sample1_24x24_t30_0157.txt*      Sample1_24x24_t30_0379.tif*
# Sample1_24x24_t30_0158.tif*      Sample1_24x24_t30_0379.txt*
# Sample1_24x24_t30_0158.txt*      Sample1_24x24_t30_0380.tif*
# Sample1_24x24_t30_0159.tif*      Sample1_24x24_t30_0380.txt*
# Sample1_24x24_t30_0159.txt*      Sample1_24x24_t30_0381.tif*
# Sample1_24x24_t30_0160.tif*      Sample1_24x24_t30_0381.txt*
# Sample1_24x24_t30_0160.txt*      Sample1_24x24_t30_0382.tif*
# Sample1_24x24_t30_0161.tif*      Sample1_24x24_t30_0382.txt*
# Sample1_24x24_t30_0161.txt*      Sample1_24x24_t30_0383.tif*
# Sample1_24x24_t30_0162.tif*      Sample1_24x24_t30_0383.txt*
# Sample1_24x24_t30_0162.txt*      Sample1_24x24_t30_0384.tif*
# Sample1_24x24_t30_0163.tif*      Sample1_24x24_t30_0384.txt*
# Sample1_24x24_t30_0163.txt*      Sample1_24x24_t30_0385.tif*
# Sample1_24x24_t30_0164.tif*      Sample1_24x24_t30_0385.txt*
# Sample1_24x24_t30_0164.txt*      Sample1_24x24_t30_0386.tif*
# Sample1_24x24_t30_0165.tif*      Sample1_24x24_t30_0386.txt*
# Sample1_24x24_t30_0165.txt*      Sample1_24x24_t30_0387.tif*
# Sample1_24x24_t30_0166.tif*      Sample1_24x24_t30_0387.txt*
# Sample1_24x24_t30_0166.txt*      Sample1_24x24_t30_0388.tif*
# Sample1_24x24_t30_0167.tif*      Sample1_24x24_t30_0388.txt*
# Sample1_24x24_t30_0167.txt*      Sample1_24x24_t30_0389.tif*
# Sample1_24x24_t30_0168.tif*      Sample1_24x24_t30_0389.txt*
# Sample1_24x24_t30_0168.txt*      Sample1_24x24_t30_0390.tif*
# Sample1_24x24_t30_0169.tif*      Sample1_24x24_t30_0390.txt*
# Sample1_24x24_t30_0169.txt*      Sample1_24x24_t30_0391.tif*
# Sample1_24x24_t30_0170.tif*      Sample1_24x24_t30_0391.txt*
# Sample1_24x24_t30_0170.txt*      Sample1_24x24_t30_0392.tif*
# Sample1_24x24_t30_0171.tif*      Sample1_24x24_t30_0392.txt*
# Sample1_24x24_t30_0171.txt*      Sample1_24x24_t30_0393.tif*
# Sample1_24x24_t30_0172.tif*      Sample1_24x24_t30_0393.txt*
# Sample1_24x24_t30_0172.txt*      Sample1_24x24_t30_0394.tif*
# Sample1_24x24_t30_0173.tif*      Sample1_24x24_t30_0394.txt*
# Sample1_24x24_t30_0173.txt*      Sample1_24x24_t30_0395.tif*
# Sample1_24x24_t30_0174.tif*      Sample1_24x24_t30_0395.txt*
# Sample1_24x24_t30_0174.txt*      Sample1_24x24_t30_0396.tif*
# Sample1_24x24_t30_0175.tif*      Sample1_24x24_t30_0396.txt*
# Sample1_24x24_t30_0175.txt*      Sample1_24x24_t30_0397.tif*
# Sample1_24x24_t30_0176.tif*      Sample1_24x24_t30_0397.txt*
# Sample1_24x24_t30_0176.txt*      Sample1_24x24_t30_0398.tif*
# Sample1_24x24_t30_0177.tif*      Sample1_24x24_t30_0398.txt*
# Sample1_24x24_t30_0177.txt*      Sample1_24x24_t30_0399.tif*
# Sample1_24x24_t30_0178.tif*      Sample1_24x24_t30_0399.txt*
# Sample1_24x24_t30_0178.txt*      Sample1_24x24_t30_0400.tif*
# Sample1_24x24_t30_0179.tif*      Sample1_24x24_t30_0400.txt*
# Sample1_24x24_t30_0179.txt*      Sample1_24x24_t30_0401.tif*
# Sample1_24x24_t30_0180.tif*      Sample1_24x24_t30_0401.txt*
# Sample1_24x24_t30_0180.txt*      Sample1_24x24_t30_0402.tif*
# Sample1_24x24_t30_0181.tif*      Sample1_24x24_t30_0402.txt*
# Sample1_24x24_t30_0181.txt*      Sample1_24x24_t30_0403.tif*
# Sample1_24x24_t30_0182.tif*      Sample1_24x24_t30_0403.txt*
# Sample1_24x24_t30_0182.txt*      Sample1_24x24_t30_0404.tif*
# Sample1_24x24_t30_0183.tif*      Sample1_24x24_t30_0404.txt*
# Sample1_24x24_t30_0183.txt*      Sample1_24x24_t30_0405.tif*
# Sample1_24x24_t30_0184.tif*      Sample1_24x24_t30_0405.txt*
# Sample1_24x24_t30_0184.txt*      Sample1_24x24_t30_0406.tif*
# Sample1_24x24_t30_0185.tif*      Sample1_24x24_t30_0406.txt*
# Sample1_24x24_t30_0185.txt*      Sample1_24x24_t30_0407.tif*
# Sample1_24x24_t30_0186.tif*      Sample1_24x24_t30_0407.txt*
# Sample1_24x24_t30_0186.txt*      Sample1_24x24_t30_0408.tif*
# Sample1_24x24_t30_0187.tif*      Sample1_24x24_t30_0408.txt*
# Sample1_24x24_t30_0187.txt*      Sample1_24x24_t30_0409.tif*
# Sample1_24x24_t30_0188.tif*      Sample1_24x24_t30_0409.txt*
# Sample1_24x24_t30_0188.txt*      Sample1_24x24_t30_0410.tif*
# Sample1_24x24_t30_0189.tif*      Sample1_24x24_t30_0410.txt*
# Sample1_24x24_t30_0189.txt*      Sample1_24x24_t30_0411.tif*
# Sample1_24x24_t30_0190.tif*      Sample1_24x24_t30_0411.txt*
# Sample1_24x24_t30_0190.txt*      Sample1_24x24_t30_0412.tif*
# Sample1_24x24_t30_0191.tif*      Sample1_24x24_t30_0412.txt*
# Sample1_24x24_t30_0191.txt*      Sample1_24x24_t30_0413.tif*
# Sample1_24x24_t30_0192.tif*      Sample1_24x24_t30_0413.txt*
# Sample1_24x24_t30_0192.txt*      Sample1_24x24_t30_0414.tif*
# Sample1_24x24_t30_0193.tif*      Sample1_24x24_t30_0414.txt*
# Sample1_24x24_t30_0193.txt*      Sample1_24x24_t30_0415.tif*
# Sample1_24x24_t30_0194.tif*      Sample1_24x24_t30_0415.txt*
# Sample1_24x24_t30_0194.txt*      Sample1_24x24_t30_0416.tif*
# Sample1_24x24_t30_0195.tif*      Sample1_24x24_t30_0416.txt*
# Sample1_24x24_t30_0195.txt*      Sample1_24x24_t30_0417.tif*
# Sample1_24x24_t30_0196.tif*      Sample1_24x24_t30_0417.txt*
# Sample1_24x24_t30_0196.txt*      Sample1_24x24_t30_0418.tif*
# Sample1_24x24_t30_0197.tif*      Sample1_24x24_t30_0418.txt*
# Sample1_24x24_t30_0197.txt*      Sample1_24x24_t30_0419.tif*
# Sample1_24x24_t30_0198.tif*      Sample1_24x24_t30_0419.txt*
# Sample1_24x24_t30_0198.txt*      Sample1_24x24_t30_0420.tif*
# Sample1_24x24_t30_0199.tif*      Sample1_24x24_t30_0420.txt*
# Sample1_24x24_t30_0199.txt*      Sample1_24x24_t30_0421.tif*
# Sample1_24x24_t30_0200.tif*      Sample1_24x24_t30_0421.txt*
# Sample1_24x24_t30_0200.txt*      Sample1_24x24_t30_0422.tif*
# Sample1_24x24_t30_0201.tif*      Sample1_24x24_t30_0422.txt*
# Sample1_24x24_t30_0201.txt*      Sample1_24x24_t30_0423.tif*
# Sample1_24x24_t30_0202.tif*      Sample1_24x24_t30_0423.txt*
# Sample1_24x24_t30_0202.txt*      Sample1_24x24_t30_0424.tif*
# Sample1_24x24_t30_0203.tif*      Sample1_24x24_t30_0424.txt*
# Sample1_24x24_t30_0203.txt*      Sample1_24x24_t30_0425.tif*
# Sample1_24x24_t30_0204.tif*      Sample1_24x24_t30_0425.txt*
# Sample1_24x24_t30_0204.txt*      Sample1_24x24_t30_0426.tif*
# Sample1_24x24_t30_0205.tif*      Sample1_24x24_t30_0426.txt*
# Sample1_24x24_t30_0205.txt*      Sample1_24x24_t30_0427.tif*
# Sample1_24x24_t30_0206.tif*      Sample1_24x24_t30_0427.txt*
# Sample1_24x24_t30_0206.txt*      Sample1_24x24_t30_0428.tif*
# Sample1_24x24_t30_0207.tif*      Sample1_24x24_t30_0428.txt*
# Sample1_24x24_t30_0207.txt*      Sample1_24x24_t30_0429.tif*
# Sample1_24x24_t30_0208.tif*      Sample1_24x24_t30_0429.txt*
# Sample1_24x24_t30_0208.txt*      Sample1_24x24_t30_0430.tif*
# Sample1_24x24_t30_0209.tif*      Sample1_24x24_t30_0430.txt*
# Sample1_24x24_t30_0209.txt*      Sample1_24x24_t30_0431.tif*
# Sample1_24x24_t30_0210.tif*      Sample1_24x24_t30_0431.txt*
# Sample1_24x24_t30_0210.txt*      Sample1_24x24_t30_0432.tif*
# Sample1_24x24_t30_0211.tif*      Sample1_24x24_t30_0432.txt*
# Sample1_24x24_t30_0211.txt*      Sample1_24x24_t30_0433.tif*
# Sample1_24x24_t30_0212.tif*      Sample1_24x24_t30_0433.txt*
# Sample1_24x24_t30_0212.txt*      Sample1_24x24_t30_0434.tif*
# Sample1_24x24_t30_0213.tif*      Sample1_24x24_t30_0434.txt*
# Sample1_24x24_t30_0213.txt*      Sample1_24x24_t30_0435.tif*
# Sample1_24x24_t30_0214.tif*      Sample1_24x24_t30_0435.txt*
# Sample1_24x24_t30_0214.txt*      Sample1_24x24_t30_0436.tif*
# Sample1_24x24_t30_0215.tif*      Sample1_24x24_t30_0436.txt*
# Sample1_24x24_t30_0215.txt*      Sample1_24x24_t30_0437.tif*
# Sample1_24x24_t30_0216.tif*      Sample1_24x24_t30_0437.txt*
# Sample1_24x24_t30_0216.txt*      Sample1_24x24_t30_0438.tif*
# Sample1_24x24_t30_0217.tif*      Sample1_24x24_t30_0438.txt*
# Sample1_24x24_t30_0217.txt*      Sample1_24x24_t30_0439.tif*
# Sample1_24x24_t30_0218.tif*      Sample1_24x24_t30_0439.txt*
# Sample1_24x24_t30_0218.txt*      Sample1_24x24_t30_0440.tif*
# Sample1_24x24_t30_0219.tif*      Sample1_24x24_t30_0440.txt*
# Sample1_24x24_t30_0219.txt*      Sample1_24x24_t30_0441.tif*
# Sample1_24x24_t30_0220.tif*      Sample1_24x24_t30_0441.txt*
# Sample1_24x24_t30_0220.txt*      Sample1_24x24_t30_scan1.csv*
# Sample1_24x24_t30_0221.tif*      Sample1_24x24_t30_scan1_mca.dat*

# %%
# %cat /Users/tfast/Desktop/SLAC_MG_0716/Sample1/Sample1_24x24_t30_0001.txt*
# Out:
# # General info
# User: SSRL\b_mehta, time: Sat Jul 16 02:38:44 2016
#
# # Temperature
# C
#
# # Counters
# sec=30, i0=3.7535e+06, i1=3.96539e+06, mon=0, bstop=1.34941e+07, Omron=105190, CH6=0, CH7=0, TEMP=0, marccd=29.9389, ICRxT=565020, OCRxT=534390, ROI1=98773, ROI2=89442, ROI3=16718, ROI4=9291, ROI5=739, ROI6=118102, ROI7=0, ROI8=0, ROI9=0, ROI10=0, RIO11=0, ROI12=0, ROI13=0, SWX=0, CCD1=0, CTEMP=0, Timer=0, pd1=0, pd2=0, pd3=0, pd4=0, pd5=0, pd6=0, pd7=0, pd8=0, pd9=0, pd10=0, pd11=0, pd12=0, pd13=0, pd14=0, pd15=0, pd16=0
#
# # Motors
# samplex=-9.52381e-09, sampley=4.52595, samplez=-18.0059, camzoom=-5.88235e-05, kap=-307.035, phi=10, omg=0.999998, gonioz=160.977, gsvert=0, gshorz=0, empty3=10, empty4=0, dethorz=-12.4003, detvert=254, detz=221.911, detpit=-30, t3v=1.14562, b3v=-0.845625, r3h=-0.7175, l3h=1.7175, theta=0, stagex=1.95012, bshorz=20.5739, bsvert=8.79974, m0v1=1.99873, m0v2=5.77919, m0h1=-3.50508, m0h2=-6.79695, empty7=20.7235, monopit=22718, monorol=61522, crystal=8.956, monvtra=-0.434081, monvgap=6.00096, monhtra=-1.10511, monhgap=15.9994, tablev1=26.9799, tablev2=40.5477, plate_y=-35.9999, plate_z=-11.3989, tableh1=9.07165, tableh2=12.1735, plate_x=4.38247e-07, plate_t=3, vort_y=3.7406, vort_x=1.52985, vort_z=-62.0245, fluo_z=-25.9179, m0bend=2.92533, m0vtran=3.9374, m0pitch=4.2146, m0horz=-5.0913, m0yaw=-3.7323, tablev=34.3805, tablep=8.4482, tableh=10.0432, tableya=2.9263, h0gap=5, h0tran=0.186, v0gap=5, v0tran=-1.532, h1gap=27.813, h1tran=8.8855, v1gap=12.652, v1tran=63.898, mono=12699.7, pico1=710.465, pico2=-182.885, pico3=486.86, t0v=0.968, b0v=4.032, l0h=2.314, r0h=2.686, t1v=70.2239, b1v=-57.5721, l1h=5.02105, r1h=22.7917, h2gap=2, h2tran=2.785, v2gap=2, v2tran=3.38, h3gap=1, h3tran=-1.2175, v3gap=0.3, v3tran=0.9955, t2v=4.38, b2v=-2.38, l2h=-1.785, r2h=3.785, saxschi=0.319922, saxsth=0.12002, saxsy=0.75, spare4=0, saxshor=33.9948, oldver=-2.88393, saxphi=0.999996, table2h=1, table2v=-20.4181, saxsver=-5.56275e-06, m99=0, cryocon=-1, tempset=20

# %% [markdown]
# * Turn metadata into a dataframe
#
# /Users/tfast/Desktop/SLAC_MG_0716/Sample1/Sample1_24x24_t30_0001.txt*

# %%
from IPython import display

# %%
import skimage.io

# %%
im = skimage.io.imread('/Users/tfast/Desktop/SLAC_MG_0716/Sample1/Sample1_24x24_t30_0010.tif')
skimage.io.imshow(im)
# Out:
# /Users/tfast/anaconda/lib/python3.5/site-packages/skimage/io/_plugins/matplotlib_plugin.py:74: UserWarning: Low image dynamic range; displaying image with stretched contrast.
#   warn("Low image dynamic range; displaying image with "

# %%
# %matplotlib inline

# %%
import dask.dataframe as dd

# %%
from whatever import *

# %%
import glob

# %%
import pandas

# %%
pandas.read_csv

# %%
from toolz.curried import *

# %%
for the_file in glob.glob(
    "/Users/tfast/Desktop/SLAC_MG_0716/Sample1/Processed/*_1D.csv"
):
    pandas.read_csv(
        the_file, names=['Q','I'], header=None
    ).iloc[:1000].set_index('Q')

# %%
metadata = pandas.read_csv("/Users/tfast/Desktop/SLAC_MG_0716/Sample1/Processed/Sample1_24x24_t30_14715979master_metadata.csv")
metadata = metadata.rename(columns={'scan#.1': 'scan'}).set_index('scan')
for c in 'xy':
    metadata['plate_'+c] = metadata['plate_'+c].apply(compose(
            first, lambda x: x.split('e',1)
        )).astype(float)

# %%
baselines = [209, 233]

# %%
dfs = []
for i, the_file in enumerate(glob.glob(
    "/Users/tfast/Desktop/SLAC_MG_0716/Sample[1-5]/Processed/*_1D.csv"
)):
    s = pandas.read_csv(
        the_file, header=None, 
        names=['Q', str(i)+'_'+str(the_file.split('_')[-2])]
    ).set_index('Q').iloc[:1000]
    dfs.append(s)
    

signals = pandas.concat(dfs, axis=1)

signals.plot(legend=None)

# %%
# %matplotlib notebook

# %% [markdown]
# > _hypothesis_ - The rolling _standard deviation_.  It will exentuate the crystalline patterns because they have larger information entropy.  The rolling deviations are then used to identify non-crystalline patterns, by some thresholding technique, that can be automated later.

# %%
# %matplotlib notebook

# %%
roll = signals.rolling(31, center=True).std().fillna(0).sum(axis=0)

# %% [markdown]
# > Identify non-crystalline states using the thresholding below.

# %%
from magical import register_jinja2_magic
env = register_jinja2_magic()

# %%
threshold = 13e3

# %%
# %%jinja2
#
# > The threshold we using is `{{threshold}}`.  This value was identified using the image below.
#
# <img src="data:image/png;base64,..."/>
# Out:
# > The threshold we using is `13000.0`.  This value was identified using the image below.
#
# <img src="data:image/png;base64,..."/>

# %%
noncrystalline = signals[roll[roll < threshold].index].columns

# %%
# %matplotlib notebook

# %%
xtal = signals.rolling(25).sum()
xtal.plot(legend=False)
# Out:
# <img src="data:image/png;base64,...">

# %%
xtal_threshold=31e3

# %%
# %%jinja2
#
# The rolling sum of the signals to find some crystalling examples.  {{xtal_threshold}}
#
# ![](data:image/png;base64,...)
# Out:
# The rolling sum of the signals to find some crystalling examples.  31000.0
#
# ![](data:image/png;base64,...)

# %%
xtal_features = xtal.columns[(xtal>xtal_threshold).any(axis=0)]

# %%
trainer =pandas.concat(
    [
        signals[xtal_features].transpose().reset_index(drop=True).set_index(
            np.array([0]*len(xtal_features))),
        signals[noncrystalline].transpose().reset_index(drop=True).set_index(
            np.array([1]*len(noncrystalline))),

    ],axis=0)

# %%
h = signals.rolling(25).std().fillna(0)

# %%
train = trainer.transpose().rolling(25).std().fillna(0).transpose()

# %%
X = pipeline.make_pipeline(
    preprocessing.RobustScaler(),
    ensemble.RandomForestClassifier(),
).fit(train.values, train.index)

# %%
signals.transpose()[X.predict(h.transpose().values)==0].transpose().plot(legend=False)
# Out:
# <img src="data:image/png;base64,...">

# %%
signals.transpose()[X.predict(h.transpose().values)==1].transpose().plot(legend=False)
# Out:
# <img src="data:image/png;base64,...">

# %%
clf = tree.DecisionTreeClassifier().fit(trainer.values, trainer.index)

# %%
roll.iloc[roll.rolling(25, center=True).std().fillna(0).sum(axis=0) < 3e5]
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-303-e1cf3b5fb7e9> in <module>()
# ----> 1 roll.iloc[roll.rolling(25, center=True).std().fillna(0).sum(axis=0) < 3e5]
#
# /Users/tfast/anaconda/lib/python3.5/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1294             return self._getitem_tuple(key)
#    1295         else:
# -> 1296             return self._getitem_axis(key, axis=0)
#    1297
#    1298     def _getitem_axis(self, key, axis=0):
#
# /Users/tfast/anaconda/lib/python3.5/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1588
#    1589         elif is_bool_indexer(key):
# -> 1590             self._has_valid_type(key, axis)
#    1591             return self._getbool_axis(key, axis=axis)
#    1592
#
# /Users/tfast/anaconda/lib/python3.5/site-packages/pandas/core/indexing.py in _has_valid_type(self, key, axis)
#    1500             if hasattr(key, 'index') and isinstance(key.index, Index):
#    1501                 if key.index.inferred_type == 'integer':
# -> 1502                     raise NotImplementedError("iLocation based boolean "
#    1503                                               "indexing on an integer type "
#    1504                                               "is not available")
#
# NotImplementedError: iLocation based boolean indexing on an integer type is not available

# %%
model = pipeline.make_pipeline(
    preprocessing.MaxAbsScaler(),
        decomposition.PCA(),a
).fit(roll[(roll!=0).all(axis=1)].transpose().values)

pandas.DataFrame(
    model.transform(roll[(roll!=0).all(axis=1)].transpose().values)
).plot(x=0, y=1, kind='scatter')
# Out:
# <img src="data:image/png;base64,...">

# %%
r = signals.rolling(20, center=True)

# %%
(signals.rolling(50, center=True).std().fillna(0)*signals).plot(legend=False)
# Out:
# <img src="data:image/png;base64,...">

# %%
# %matplotlib notebook

# %%
signals[baselines].plot()

# %%
pandas.concat(l,axis=1, join='inner').plot(legend=None)

# %%
df = dd.read_csv("/Users/tfast/Desktop/SLAC_MG_0716/Sample1/Processed/*_1D.csv")
